# %% [markdown]
# #

# %%
from transformers import pipeline

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "gpt2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

print("✅ Model Loaded Successfully")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       2
#       3 model_name = "gpt2"
#       4
#       5 tokenizer = AutoTokenizer.from_pretrained(model_name)
# ----> 6 model = AutoModelForCausalLM.from_pretrained(model_name)
#       7
#       8 print("✅ Model Loaded Successfully")
#
# File ~/ai-env/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:406, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     404         if parent_quant is not None:
#     405             config.quantization_config = parent_quant
# --> 406     return model_class.from_pretrained(
#     407         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     408     )
#     409 raise ValueError(
#     410     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     411     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     412 )
#
# File ~/ai-env/lib/python3.12/site-packages/transformers/modeling_utils.py:4229, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, fusion_config, disable_mmap, *model_args, **kwargs)
#    4224     logger.warning_once(
#    4225         "A kernel_config was provided but use_kernels is False; setting use_kernels=True automatically. To suppress this warning, explicitly set use_kernels to True."
#    4226     )
#    4227     use_kernels = True
# -> 4229 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4230     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4231     variant=variant,
#    4232     gguf_file=gguf_file,
#    4233     use_safetensors=use_safetensors,
#    4234     download_kwargs=download_kwargs_with_commit,
#    4235     user_agent=user_agent,
#    4236     is_remote_code=cls.is_remote_code(),
#    4237     transformers_explicit_filename=getattr(config, "transformers_weights", None),
#    4238     tqdm_class=tqdm_class,
#    4239 )
#    4241 is_quantized = hf_quantizer is not None
#    4243 # Find the correct dtype based on current state
#
# File ~/ai-env/lib/python3.12/site-packages/transformers/modeling_utils.py:678, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, variant, gguf_file, use_safetensors, user_agent, is_remote_code, transformers_explicit_filename, download_kwargs, tqdm_class)
#     666 can_auto_convert = (
#     667     not is_offline_mode()  # for obvious reasons
#     668     # If we are in a CI environment or in a pytest run, we prevent the conversion
#    (...)    671     and subfolder == ""  # converter bot does not work on subfolders
#     672 )
#     674 try:
#     675     # Load from URL or cache if already cached
#     676     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#     677     # result when internet is up, the repo and revision exist, but the file does not.
# --> 678     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#     680     # Try safetensors files first if not already found
#     681     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#     682         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File ~/ai-env/lib/python3.12/site-packages/transformers/utils/hub.py:293, in cached_file(path_or_repo_id, filename, **kwargs)
#     238 def cached_file(
#     239     path_or_repo_id: str | os.PathLike,
#     240     filename: str,
#     241     **kwargs,
#     242 ) -> str | None:
#     243     """
#     244     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     245
#    (...)    291     ```
#     292     """
# --> 293     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     294     file = file[0] if file is not None else file
#     295     return file
#
# File ~/ai-env/lib/python3.12/site-packages/transformers/utils/hub.py:437, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     434 try:
#     435     if len(full_filenames) == 1:
#     436         # This is slightly better for only 1 file
# --> 437         hf_hub_download(
#     438             path_or_repo_id,
#     439             filenames[0],
#     440             subfolder=None if len(subfolder) == 0 else subfolder,
#     441             repo_type=repo_type,
#     442             revision=revision,
#     443             cache_dir=cache_dir,
#     444             user_agent=user_agent,
#     445             force_download=force_download,
#     446             proxies=proxies,
#     447             token=token,
#     448             local_files_only=local_files_only,
#     449             tqdm_class=tqdm_class,
#     450         )
#     451     else:
#     452         snapshot_download(
#     453             path_or_repo_id,
#     454             allow_patterns=full_filenames,
#    (...)    463             tqdm_class=tqdm_class,
#     464         )
#
# File ~/ai-env/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/ai-env/lib/python3.12/site-packages/huggingface_hub/file_download.py:1016, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     995     return _hf_hub_download_to_local_dir(
#     996         # Destination
#     997         local_dir=local_dir,
#    (...)   1013         dry_run=dry_run,
#    1014     )
#    1015 else:
# -> 1016     return _hf_hub_download_to_cache_dir(
#    1017         # Destination
#    1018         cache_dir=cache_dir,
#    1019         # File info
#    1020         repo_id=repo_id,
#    1021         filename=filename,
#    1022         repo_type=repo_type,
#    1023         revision=revision,
#    1024         # HTTP info
#    1025         endpoint=endpoint,
#    1026         etag_timeout=etag_timeout,
#    1027         headers=hf_headers,
#    1028         token=token,
#    1029         # Additional options
#    1030         local_files_only=local_files_only,
#    1031         force_download=force_download,
#    1032         tqdm_class=tqdm_class,
#    1033         dry_run=dry_run,
#    1034     )
#
# File ~/ai-env/lib/python3.12/site-packages/huggingface_hub/file_download.py:1238, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1235 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1237 with WeakFileLock(lock_path):
# -> 1238     _download_to_tmp_and_move(
#    1239         incomplete_path=Path(blob_path + ".incomplete"),
#    1240         destination_path=Path(blob_path),
#    1241         url_to_download=url_to_download,
#    1242         headers=headers,
#    1243         expected_size=expected_size,
#    1244         filename=filename,
#    1245         force_download=force_download,
#    1246         etag=etag,
#    1247         xet_file_data=xet_file_data,
#    1248         tqdm_class=tqdm_class,
#    1249     )
#    1250     if not os.path.exists(pointer_path):
#    1251         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/ai-env/lib/python3.12/site-packages/huggingface_hub/file_download.py:1861, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, headers, expected_size, filename, force_download, etag, xet_file_data, tqdm_class)
#    1859 if xet_file_data is not None and is_xet_available():
#    1860     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1861     xet_get(
#    1862         incomplete_path=tmp_path,
#    1863         xet_file_data=xet_file_data,
#    1864         headers=headers,
#    1865         expected_size=expected_size,
#    1866         displayed_filename=filename,
#    1867         tqdm_class=tqdm_class,
#    1868     )
#    1869 else:
#    1870     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File ~/ai-env/lib/python3.12/site-packages/huggingface_hub/file_download.py:566, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     563     _prev = current
#     565 try:
# --> 566     with session.new_file_download_group(
#     567         token_refresh_url=xet_file_data.refresh_route,
#     568         token_refresh_headers=headers,
#     569         custom_headers=xet_headers,
#     570         progress_callback=_on_progress,
#     571     ) as group:
#     572         group.start_download_file(
#     573             XetFileInfo(xet_file_data.file_hash, expected_size), str(incomplete_path.absolute())
#     574         )
#     575 except KeyboardInterrupt:
#
# KeyboardInterrupt:

# %% [markdown]
# or

# %% [markdown]
# from huggingface_hub import snapshot_download
#
# snapshot_download(
#     repo_id="HuggingFaceTB/SmolLM2-135M",
#     local_dir="./SmolLM2"
# )

# %%
result = generator(
    "Artificial Intelligence will",
    max_new_tokens=50
)

print(result[0]["generated_text"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = generator(
#       2     "Artificial Intelligence will",
#       3     max_new_tokens=50
#       4 )
#
# NameError: name 'generator' is not defined

# %%
find ~/.cache/huggingface/hub/models--gpt2 -name "*.safetensors" -ls
# Out:
#   Cell In[7], line 1
#     find ~/.cache/huggingface/hub/models--gpt2 -name "*.safetensors" -ls
#          ^
# SyntaxError: invalid syntax
